# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
a = np.loadtxt("4a4b.txt")

# %%
a
# Out:
# array([[0.    , 2.5   , 2.5   ],
#        [0.1   , 2.5015, 2.5005],
#        [0.2   , 2.503 , 2.501 ],
#        [0.3   , 2.521 , 2.507 ],
#        [0.4   , 2.614 , 2.538 ],
#        [0.5   , 2.8105, 2.6035],
#        [0.6   , 3.325 , 2.775 ],
#        [0.7   , 4.1735, 3.0925],
#        [0.8   , 4.6195, 3.617 ],
#        [0.9   , 5.    , 4.261 ],
#        [1.    , 5.    , 5.    ]])

# %%
fig, ax = plt.subplots(figsize=(10,8))

ax.plot(a[:,0], a[:,1], label='4a')
ax.plot(a[:,0], a[:,2], label='4b')
ax.legend()
ax.set_xlabel("p")
ax.set_ylabel("costs")
# Out:
# Text(0, 0.5, 'costs')
